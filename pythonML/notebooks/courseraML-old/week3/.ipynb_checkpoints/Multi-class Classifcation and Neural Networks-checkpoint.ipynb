# %%
import scipy.io
import numpy as np
from matplotlib import pyplot as plt
import random

# %%
mat_dict = scipy.io.loadmat('./data/ex3data1.mat')
X = mat_dict['X']
print(X.shape)
y = mat_dict['y']
print(y.size)
input_layer_size  = 400 # % 20x20 Input Images of Digits
num_labels = 10
# Out:
# (5000, 400)
# 5000

# %%
m = X.shape[0]
print(m)
# Out:
# 5000

# %%
print(X[1].shape)
print(X[1].reshape((20, 20)).shape)
for i in random.sample(range(5000), 2):
    plt.imshow(X[i].reshape((20, 20)).T, cmap = 'gray',interpolation = 'bicubic') #, interpolation = 'bicubic'
    plt.show()
    print(y[i])
# Out:
# (400,)
# (20, 20)
# [9]
# [5]

# %%
weights_dict = scipy.io.loadmat('./data/ex3weights.mat')
Theta1 = weights_dict['Theta1']
print(Theta1.shape)
Theta2 = weights_dict['Theta2']
print(Theta2.shape)
# Out:
# (25, 401)
# (10, 26)

# %% [markdown]
# <img src="./images/nn.png" style="width:650px;height:100px;">

# %%
from functions import predict
predict(Theta1, Theta2, X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c6c0a8f6593d> in <module>()
#       1 from functions import predict
# ----> 2 predict(Theta1, Theta2, X)
#
# TypeError: predict() takes 0 positional arguments but 3 were given
