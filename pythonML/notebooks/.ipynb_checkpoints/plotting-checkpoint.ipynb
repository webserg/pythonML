# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(2,3, '.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3 ,2, '.')
canvas.print_png('webserg.png')

# %%
# %%html
# <img src='webserg.png'/>
# Out:
# <img src='webserg.png'/>

# %%
plt.figure()
plt.plot(3,2,'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(3,2,'o')
plt.plot(5,8,'o')
plt.plot(2,2,'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x119c05caa58>,
#  <matplotlib.lines.Line2D at 0x119c05a5208>,
#  <matplotlib.lines.Line2D at 0x119c05accc0>,
#  <matplotlib.spines.Spine at 0x119c05a5f60>,
#  <matplotlib.spines.Spine at 0x119c08b73c8>,
#  <matplotlib.spines.Spine at 0x119c05ac128>,
#  <matplotlib.spines.Spine at 0x119c05ac390>,
#  <matplotlib.axis.XAxis at 0x119c05ac5c0>,
#  <matplotlib.axis.YAxis at 0x119c05b8198>,
#  <matplotlib.text.Text at 0x119c05cf940>,
#  <matplotlib.text.Text at 0x119c05cf9b0>,
#  <matplotlib.text.Text at 0x119c05cfa20>,
#  <matplotlib.patches.Rectangle at 0x119c05cfa58>]

# %%
import numpy as np
x = np.array([1,2,3,4,5,6,7,8])
y = x
plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
x = np.array([1,2,3,4,5,6,7,8])
y = x
colors = ['green'] * (len(x) - 1)
colors.append('red')
plt.figure()
plt.scatter(x,y,s=100,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zip_g = zip ([1,2,3],[4,5,6])
list(zip_g)
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
zip_g = zip ([1,2,3],[4,5,6])
x,y = zip(*zip_g)
print(x)
y
# Out:
# (1, 2, 3)
# (4, 5, 6)

# %%
import numpy as np
x = np.array([1,2,3,4,5,6,7,8])
quadr_data = x**2
plt.figure()
plt.plot(x, '-o', quadr_data ,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x119c0547160>,
#  <matplotlib.lines.Line2D at 0x119c0547400>]
